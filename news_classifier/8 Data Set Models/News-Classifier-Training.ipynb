# %%
##### Categories to classify into: BUSINESS, ENTERTAINMENT, HEALTH, SCIENCE, SPORTS, TECH, U.S. NEWS, WORLD NEWS

###### Data from "RishabhMisraHuffPostDataset" & "GoogleNewsDataset"

###### BUSINESS - 13444
###### Entertainment - 9163
###### HEALTH - 9623
###### SCIENCE - 6565
###### SPORTS - 13306
###### TECH - 9037
###### U.S. NEWS - 12377
###### WORLD NEWS - 10328
###### Total - 83843

# %%
import pandas as pd
df = pd.read_csv("../data/8TrainingData.csv")
df
# Out:
#                             _id category  \
# 0      65583f2abf0ca14ca2d80f26   HEALTH
# 1      65583f2abf0ca14ca2d80f99   HEALTH
# 2      65583f2abf0ca14ca2d80fcf   HEALTH
# 3      65583f2abf0ca14ca2d81083   HEALTH
# 4      65583f2abf0ca14ca2d8108a   HEALTH
# ...                         ...      ...
# 83838  65591709853abc5434799cc1   HEALTH
# 83839  65591709853abc5434799cdd   HEALTH
# 83840  6559170a853abc5434799d69   HEALTH
# 83841  6559170a853abc5434799da3   HEALTH
# 83842  6559170a853abc5434799e27   HEALTH
#
#                                                 headline
# 0      To The People Who Say ‘I’m Tired’ When Someone...
# 1      Eating Shake Shack Made Me Feel Healthier Than...
# 2      How To Stay Updated On The News Without Losing...
# 3      27 Perfect Tweets About Whole30 That Will Make...
# 4             The Real Reason Your Hands Are Always Cold
# ...                                                  ...
# 83838  New CA Hospital Safety Ratings Released: 2 Get...
# 83839  Dr. Bitner says sleeping is not a waste of tim...
# 83840       Virginia, DC Hospital Safety Grades For 2019
# 83841  End-of-life education, legislation gets backin...
# 83842  'Alarming rise in vaping' among R.I. high scho...
#
# [83843 rows x 3 columns]

# %%
df.drop(columns=["_id"], inplace=True)
df
# Out:
#       category                                           headline
# 0       HEALTH  To The People Who Say ‘I’m Tired’ When Someone...
# 1       HEALTH  Eating Shake Shack Made Me Feel Healthier Than...
# 2       HEALTH  How To Stay Updated On The News Without Losing...
# 3       HEALTH  27 Perfect Tweets About Whole30 That Will Make...
# 4       HEALTH         The Real Reason Your Hands Are Always Cold
# ...        ...                                                ...
# 83838   HEALTH  New CA Hospital Safety Ratings Released: 2 Get...
# 83839   HEALTH  Dr. Bitner says sleeping is not a waste of tim...
# 83840   HEALTH       Virginia, DC Hospital Safety Grades For 2019
# 83841   HEALTH  End-of-life education, legislation gets backin...
# 83842   HEALTH  'Alarming rise in vaping' among R.I. high scho...
#
# [83843 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
label = le.fit_transform(df["category"])

df.drop(columns=["category"], inplace=True)

df["category"] = label
df
# Out:
#                                                 headline  category
# 0      To The People Who Say ‘I’m Tired’ When Someone...         2
# 1      Eating Shake Shack Made Me Feel Healthier Than...         2
# 2      How To Stay Updated On The News Without Losing...         2
# 3      27 Perfect Tweets About Whole30 That Will Make...         2
# 4             The Real Reason Your Hands Are Always Cold         2
# ...                                                  ...       ...
# 83838  New CA Hospital Safety Ratings Released: 2 Get...         2
# 83839  Dr. Bitner says sleeping is not a waste of tim...         2
# 83840       Virginia, DC Hospital Safety Grades For 2019         2
# 83841  End-of-life education, legislation gets backin...         2
# 83842  'Alarming rise in vaping' among R.I. high scho...         2
#
# [83843 rows x 2 columns]

# %%
import en_core_web_lg

nlp = en_core_web_lg.load()

def nlpify(text):
    text = str(text)
    return nlp(text).vector

df["headline"] = df["headline"].apply(nlpify)

# %%
df
# Out:
#                                                 headline  category
# 0      [0.37533942, 0.95536953, -0.74450433, -3.20085...         2
# 1      [0.3806063, -0.2258882, -1.0344046, -0.5882237...         2
# 2      [1.7622063, 0.19124928, -2.59872, -1.8299657, ...         2
# 3      [0.030336391, -0.96273106, -1.6066481, -1.4785...         2
# 4      [-0.41738123, 1.1906976, 0.17487374, 2.0997024...         2
# ...                                                  ...       ...
# 83838  [0.15706618, -3.565367, 4.8407087, 2.6693187, ...         2
# 83839  [-0.74048406, 3.4366226, -2.8612766, -0.718307...         2
# 83840  [-2.7601447, -2.35395, 0.95709276, 2.2722, 2.5...         2
# 83841  [-3.1292198, -1.2337929, -0.08367782, 3.700286...         2
# 83842  [-0.70182693, 0.16861643, 0.96873915, 0.606225...         2
#
# [83843 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

X = df["headline"]
y = df["category"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
import numpy as np

X_train_2d = np.stack(X_train)
X_test_2d = np.stack(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

logisticregression = LogisticRegression()
logisticregression.fit(X_train_2d, y_train)

y_pred = logisticregression.predict(X_test_2d)

classification_repo = classification_report(y_true=y_test, y_pred=y_pred, target_names=["BUSINESS", "ENTERTAINMENT",  "HEALTH", "SCIENCE", "SPORTS", "TECH", "U.S. NEWS", "WORLD NEWS"])
print(classification_repo)
# Out:
#                precision    recall  f1-score   support
#
#      BUSINESS       0.72      0.70      0.71      4100
# ENTERTAINMENT       0.75      0.78      0.77      2751
#        HEALTH       0.70      0.75      0.72      2822
#       SCIENCE       0.79      0.81      0.80      1924
#        SPORTS       0.87      0.86      0.86      4050
#          TECH       0.81      0.75      0.78      2724
#     U.S. NEWS       0.74      0.76      0.75      3653
#    WORLD NEWS       0.83      0.81      0.82      3129
#
#      accuracy                           0.78     25153
#     macro avg       0.78      0.78      0.78     25153
#  weighted avg       0.78      0.78      0.78     25153
# /usr/local/python/3.12.0/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
logisticregression2 = LogisticRegression(class_weight="balanced")
logisticregression2.fit(X_train_2d, y_train)

y_pred2 = logisticregression2.predict(X_test_2d)

classification_repo2 = classification_report(y_true=y_test, y_pred=y_pred2, target_names=["BUSINESS", "ENTERTAINMENT", "HEALTH", "SCIENCE", "SPORTS", "TECH", "U.S. NEWS", "WORLD NEWS"])
print(classification_repo2)
# Out:
#                precision    recall  f1-score   support
#
#      BUSINESS       0.75      0.66      0.70      4100
# ENTERTAINMENT       0.73      0.80      0.76      2751
#        HEALTH       0.68      0.76      0.72      2822
#       SCIENCE       0.74      0.84      0.79      1924
#        SPORTS       0.89      0.84      0.86      4050
#          TECH       0.78      0.77      0.78      2724
#     U.S. NEWS       0.76      0.75      0.75      3653
#    WORLD NEWS       0.82      0.81      0.82      3129
#
#      accuracy                           0.77     25153
#     macro avg       0.77      0.78      0.77     25153
#  weighted avg       0.77      0.77      0.77     25153
# /usr/local/python/3.12.0/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
