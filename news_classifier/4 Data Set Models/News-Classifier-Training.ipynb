# %%
##### Categories to classify into: BUSINESS, ENTERTAINMENT, HEALTH, SCIENCE, SPORTS, TECH, U.S. NEWS, WORLD NEWS

###### BUSINESS - 13444
###### Entertainment - 9163
###### HEALTH - 6694
###### SCIENCE - 6565
###### SPORTS - 13306
###### TECH - 9037
###### U.S. NEWS - 1377
###### WORLD NEWS - 10328
###### Total - 69914

# %%
import pandas as pd
df = pd.read_csv("../data/4TrainingData.csv")
df
# Out:
#                             _id    category  \
# 0      65583f2abf0ca14ca2d80f26      HEALTH
# 1      65583f2abf0ca14ca2d80f99      HEALTH
# 2      65583f2abf0ca14ca2d80fcf      HEALTH
# 3      65583f2abf0ca14ca2d81083      HEALTH
# 4      65583f2abf0ca14ca2d8108a      HEALTH
# ...                         ...         ...
# 69909  6556fe4fa4077f3e93fde3e6  WORLD NEWS
# 69910  6556fe4fa4077f3e93fde3e7  WORLD NEWS
# 69911  6556fe4fa4077f3e93fde3e8  WORLD NEWS
# 69912  6556fe4fa4077f3e93fde3e9  WORLD NEWS
# 69913  6556fe4fa4077f3e93fde3ea  WORLD NEWS
#
#                                                 headline  \
# 0      To The People Who Say ‘I’m Tired’ When Someone...
# 1      Eating Shake Shack Made Me Feel Healthier Than...
# 2      How To Stay Updated On The News Without Losing...
# 3      27 Perfect Tweets About Whole30 That Will Make...
# 4             The Real Reason Your Hands Are Always Cold
# ...                                                  ...
# 69909  Hamas horrors you luckily won't see -- glimpse...
# 69910  UN warns ‘civil order’ declining in Gaza as th...
# 69911  Russian security forces remove pro-Palestinian...
# 69912  Israel ‘Expanding’ War Operations in Gaza: Ham...
# 69913  Crisis in Gaza as Israel warns of long war wit...
#
#                                                  authors  \
# 0      The Mighty, ContributorWe face disability, dis...
# 1      Colleen Werner, ContributorCampus Editor-at-Large
# 2                                         Lindsay Holmes
# 3                                         Lindsay Holmes
# 4      Refinery29, ContributorThe #1 new-media brand ...
# ...                                                  ...
# 69909                                                NaN
# 69910                                                NaN
# 69911                                                NaN
# 69912                                                NaN
# 69913                                                NaN
#
#                                                     link  \
# 0      https://www.huffingtonpost.com/entry/to-the-pe...
# 1      https://www.huffingtonpost.com/entry/eating-sh...
# 2      https://www.huffingtonpost.com/entry/anxiety-f...
# 3      https://www.huffingtonpost.com/entry/tweets-ab...
# 4      https://www.huffingtonpost.com/entry/the-real-...
# ...                                                  ...
# 69909                                                NaN
# 69910                                                NaN
# 69911                                                NaN
# 69912                                                NaN
# 69913                                                NaN
#
#                                        short_description        date
# 0      When you feel like this, it’s important to kno...  2018-01-16
# 1      I can vividly remember the first time I felt f...  2018-01-12
# 2         Because it's only becoming more of a struggle.  2018-01-12
# 3      "The only Whole30 I want to participate in is ...  2018-01-10
# 4      Essentially, your hands are kept warm thanks t...  2018-01-10
# ...                                                  ...         ...
# 69909                                                NaN         NaN
# 69910                                                NaN         NaN
# 69911                                                NaN         NaN
# 69912                                                NaN         NaN
# 69913                                                NaN         NaN
#
# [69914 rows x 7 columns]

# %%
df.drop(columns=["_id", "link", "short_description", "authors", "date"], inplace=True)
df
# Out:
#          category                                           headline
# 0          HEALTH  To The People Who Say ‘I’m Tired’ When Someone...
# 1          HEALTH  Eating Shake Shack Made Me Feel Healthier Than...
# 2          HEALTH  How To Stay Updated On The News Without Losing...
# 3          HEALTH  27 Perfect Tweets About Whole30 That Will Make...
# 4          HEALTH         The Real Reason Your Hands Are Always Cold
# ...           ...                                                ...
# 69909  WORLD NEWS  Hamas horrors you luckily won't see -- glimpse...
# 69910  WORLD NEWS  UN warns ‘civil order’ declining in Gaza as th...
# 69911  WORLD NEWS  Russian security forces remove pro-Palestinian...
# 69912  WORLD NEWS  Israel ‘Expanding’ War Operations in Gaza: Ham...
# 69913  WORLD NEWS  Crisis in Gaza as Israel warns of long war wit...
#
# [69914 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
label = le.fit_transform(df["category"])

df.drop(columns=["category"], inplace=True)

df["category"] = label

df
# Out:
#                                                 headline  category
# 0      To The People Who Say ‘I’m Tired’ When Someone...         2
# 1      Eating Shake Shack Made Me Feel Healthier Than...         2
# 2      How To Stay Updated On The News Without Losing...         2
# 3      27 Perfect Tweets About Whole30 That Will Make...         2
# 4             The Real Reason Your Hands Are Always Cold         2
# ...                                                  ...       ...
# 69909  Hamas horrors you luckily won't see -- glimpse...         7
# 69910  UN warns ‘civil order’ declining in Gaza as th...         7
# 69911  Russian security forces remove pro-Palestinian...         7
# 69912  Israel ‘Expanding’ War Operations in Gaza: Ham...         7
# 69913  Crisis in Gaza as Israel warns of long war wit...         7
#
# [69914 rows x 2 columns]

# %%
import en_core_web_lg

nlp = en_core_web_lg.load()

def nlpify(text):
    text = str(text)
    return nlp(text).vector

df["headline"] = df["headline"].apply(nlpify)

# %%
df
# Out:
#                                                 headline  category
# 0      [0.37533942, 0.95536953, -0.74450433, -3.20085...         2
# 1      [0.3806063, -0.2258882, -1.0344046, -0.5882237...         2
# 2      [1.7622063, 0.19124928, -2.59872, -1.8299657, ...         2
# 3      [0.030336391, -0.96273106, -1.6066481, -1.4785...         2
# 4      [-0.41738123, 1.1906976, 0.17487374, 2.0997024...         2
# ...                                                  ...       ...
# 69909  [0.09013114, 4.4682155, -4.387745, -0.36629754...         7
# 69910  [0.3525113, -0.39149398, -1.7636962, -0.174538...         7
# 69911  [-1.4177073, 1.1756309, -2.7592795, 3.8519273,...         7
# 69912  [1.1641855, -0.43473154, 2.7479124, 0.8667539,...         7
# 69913  [-1.285388, -0.46774504, -0.27410778, 2.382957...         7
#
# [69914 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

X = df["headline"]
y = df["category"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
import numpy as np

X_train_2d = np.stack(X_train)
X_test_2d = np.stack(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

logisticregression = LogisticRegression()
logisticregression.fit(X_train_2d, y_train)

y_pred = logisticregression.predict(X_test_2d)

classification_repo = classification_report(y_true=y_test, y_pred=y_pred, target_names=["BUSINESS", "ENTERTAINMENT",  "HEALTH", "SCIENCE", "SPORTS", "TECH", "U.S. NEWS", "WORLD NEWS"])
print(classification_repo)
# Out:
# /usr/local/python/3.12.0/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#                precision    recall  f1-score   support
#
#      BUSINESS       0.75      0.75      0.75      4093
# ENTERTAINMENT       0.78      0.81      0.80      2733
#        HEALTH       0.70      0.74      0.72      2003
#       SCIENCE       0.81      0.81      0.81      1956
#        SPORTS       0.88      0.88      0.88      3995
#          TECH       0.81      0.77      0.79      2720
#     U.S. NEWS       0.52      0.42      0.47       391
#    WORLD NEWS       0.85      0.85      0.85      3084
#
#      accuracy                           0.80     20975
#     macro avg       0.76      0.76      0.76     20975
#  weighted avg       0.80      0.80      0.80     20975

# %%
logisticregression2 = LogisticRegression(class_weight="balanced")
logisticregression2.fit(X_train_2d, y_train)

y_pred2 = logisticregression2.predict(X_test_2d)

classification_repo2 = classification_report(y_true=y_test, y_pred=y_pred2, target_names=["BUSINESS", "ENTERTAINMENT", "HEALTH", "SCIENCE", "SPORTS", "TECH", "U.S. NEWS", "WORLD NEWS"])
print(classification_repo2)
# Out:
#                precision    recall  f1-score   support
#
#      BUSINESS       0.81      0.66      0.73      4093
# ENTERTAINMENT       0.77      0.79      0.78      2733
#        HEALTH       0.66      0.77      0.71      2003
#       SCIENCE       0.79      0.83      0.81      1956
#        SPORTS       0.91      0.83      0.87      3995
#          TECH       0.79      0.78      0.79      2720
#     U.S. NEWS       0.25      0.72      0.37       391
#    WORLD NEWS       0.86      0.82      0.84      3084
#
#      accuracy                           0.78     20975
#     macro avg       0.73      0.78      0.74     20975
#  weighted avg       0.80      0.78      0.78     20975
# /usr/local/python/3.12.0/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
